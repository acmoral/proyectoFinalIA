# %%
# !pip install jams
# Out:
# Requirement already satisfied: jams in /usr/local/lib/python3.10/dist-packages (0.3.4)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from jams) (2.0.3)
# Requirement already satisfied: sortedcontainers>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from jams) (2.4.0)
# Requirement already satisfied: jsonschema>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from jams) (4.19.2)
# Requirement already satisfied: numpy>=1.8.0 in /usr/local/lib/python3.10/dist-packages (from jams) (1.25.2)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from jams) (1.16.0)
# Requirement already satisfied: decorator in /usr/local/lib/python3.10/dist-packages (from jams) (4.4.2)
# Requirement already satisfied: mir-eval>=0.5 in /usr/local/lib/python3.10/dist-packages (from jams) (0.7)
# Requirement already satisfied: attrs>=22.2.0 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=3.0.0->jams) (23.2.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=3.0.0->jams) (2023.12.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=3.0.0->jams) (0.35.1)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=3.0.0->jams) (0.18.1)
# Requirement already satisfied: scipy>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from mir-eval>=0.5->jams) (1.11.4)
# Requirement already satisfied: future in /usr/local/lib/python3.10/dist-packages (from mir-eval>=0.5->jams) (0.18.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas->jams) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->jams) (2023.4)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas->jams) (2024.1)
# Collecting pretty_midi
#   Downloading pretty_midi-0.2.10.tar.gz (5.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.6/5.6 MB 15.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: numpy>=1.7.0 in /usr/local/lib/python3.10/dist-packages (from pretty_midi) (1.25.2)
# Collecting mido>=1.1.16 (from pretty_midi)
#   Downloading mido-1.3.2-py3-none-any.whl (54 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.6/54.6 kB 8.5 MB/s eta 0:00:00
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from pretty_midi) (1.16.0)
# Collecting packaging~=23.1 (from mido>=1.1.16->pretty_midi)
#   Downloading packaging-23.2-py3-none-any.whl (53 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.0/53.0 kB 8.4 MB/s eta 0:00:00
# Building wheels for collected packages: pretty_midi
#   Building wheel for pretty_midi (setup.py) ... done
#   Created wheel for pretty_midi: filename=pretty_midi-0.2.10-py3-none-any.whl size=5592289 sha256=d381958d3be073368c7871bb62cec6e2fad0c5c9e3309f3f468f6ca73411bdf7
#   Stored in directory: /root/.cache/pip/wheels/cd/a5/30/7b8b7f58709f5150f67f98fde4b891ebf0be9ef07a8af49f25
# Successfully built pretty_midi
# Installing collected packages: packaging, mido, pretty_midi
#   Attempting uninstall: packaging
#     Found existing installation: packaging 24.0
#     Uninstalling packaging-24.0:
#       Successfully uninstalled packaging-24.0
# Successfully installed mido-1.3.2 packaging-23.2 pretty_midi-0.2.10

# %%
# !pip install pretty_midi

# %%
# !pip install sox
# Out:
# Collecting sox
#   Downloading sox-1.5.0.tar.gz (63 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.9/63.9 kB 1.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: numpy>=1.9.0 in /usr/local/lib/python3.10/dist-packages (from sox) (1.25.2)
# Requirement already satisfied: typing-extensions>=3.7.4.2 in /usr/local/lib/python3.10/dist-packages (from sox) (4.11.0)
# Building wheels for collected packages: sox
#   Building wheel for sox (setup.py) ... done
#   Created wheel for sox: filename=sox-1.5.0-py3-none-any.whl size=40038 sha256=30ad25a8fbd1c360451d87753c31655da366952fa93d6bf63548f299d9436c39
#   Stored in directory: /root/.cache/pip/wheels/74/e7/7b/8033be3ec5e4994595d01269fc9657c8fd83a0dcbf8536666a
# Successfully built sox
# Installing collected packages: sox
# Successfully installed sox-1.5.0

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/Colab Notebooks
# Out:
# /content/drive/MyDrive/Colab Notebooks

# %%
import jams
import os
import matplotlib.pyplot as plt
#este modulo es local (interpreter.py) y contiene las funciones que se usan para visualizar los jams
import interpreter as itp
## Change This Cell!
gs_path = "/content/drive/MyDrive/Colab Notebooks/data/"
anno_dir = "annotation/"
excerpt = "05_Jazz2-187-F#_comp.jams"
jam = jams.load(os.path.join(gs_path+anno_dir, excerpt))
instructed_chords = jam.search(namespace='chord')[0]
performed_chords = jam.search(namespace='chord')[1]
fig = plt.figure(figsize=(8,7), dpi=300)
ax1 = plt.subplot(211)
itp.visualize_jams_pt(jam) #pt for pitch track
ax2 = plt.subplot(212, sharex=ax1)
itp.tablaturize_jams(jam)
plt.xlim(4.9, 15) # this is the time window in seconds that I'm plotting

itp.add_annotations(ax1, performed_chords, ygrow_ratio=0.04, label_xoffset=0.06, label_yoffset=2)
itp.add_annotations(ax2, instructed_chords, ygrow_ratio=0.2, label_xoffset=0.06, label_yoffset=-0.4)
plt.show()
